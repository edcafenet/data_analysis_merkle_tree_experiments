# %%
import pickle
import numpy as np

# %%
path = '/home/eddie/experiments_results/real_robots/merkle_tree_statistics/'

MERKLE_CREATION = pickle.load(open(path + "merkle_creation.pickle", "rb"))
PROOF_GENERATION = pickle.load(open(path + "proof_generation.pickle", "rb"))
PROOF_VALIDATION = pickle.load(open(path + "proof_validation.pickle", "rb"))

# %%
MERKLE_CREATION
# Out:
# array([[0.00198388, 0.00186086, 0.00183082, 0.00183082, 0.00183105,
#         0.00186181, 0.00183082, 0.00186205, 0.00183105, 0.00183105,
#         0.00235009, 0.00192213, 0.00192213, 0.00189209, 0.00201392,
#         0.00192189, 0.00192189, 0.00189185, 0.00189185, 0.00192308,
#         0.00189185, 0.00189185, 0.00192285, 0.00210595, 0.00213599,
#         0.00189209, 0.00192308, 0.00189209, 0.00189209, 0.00189209,
#         0.00210619, 0.00186181, 0.00183082, 0.00183082, 0.00186181,
#         0.00183082, 0.00204492, 0.00186205, 0.00183105, 0.00186181,
#         0.00186181, 0.00186181, 0.00183105, 0.00183082, 0.00186205,
#         0.00183105, 0.00186205, 0.00183105, 0.00183105, 0.00201511,
#         0.00186205, 0.00183105, 0.00186205, 0.00183105, 0.00183105,
#         0.00183105, 0.00186205, 0.00186205, 0.00186086, 0.00186086,
#         0.00186181, 0.00186086, 0.00186205, 0.00186205, 0.00183105,
#         0.00186205, 0.00186205, 0.00186205, 0.00183201, 0.00186205,
# ...

# %%
np.mean(MERKLE_CREATION[-3])
# Out:
# 0.1677975058555603

# %%
np.std(MERKLE_CREATION[-3])
# Out:
# 0.0018716380656832777

# %%
np.mean(PROOF_GENERATION[-3])
# Out:
# 0.0015753436088562012

# %%
np.std(PROOF_GENERATION[-3])
# Out:
# 3.617263951206269e-05

# %%
np.mean(PROOF_VALIDATION[-3])
# Out:
# 0.0018875241279602052

# %%
np.std(PROOF_VALIDATION[-3])
# Out:
# 9.376852907617935e-05
